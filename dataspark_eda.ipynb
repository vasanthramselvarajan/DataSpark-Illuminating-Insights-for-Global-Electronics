# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_complete=pd.read_csv("df_complete.csv")
pd.set_option('display.max_column',50)
df_complete.head(10)


# CustomerKey  Gender	Name	City  State Code  State  Zip Code	Country  Continent	  Birthday
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
# 5        366002          3   1/1/2016     1/12/2016       266019         0
# 6        366004          1   1/1/2016           NaN      1107461        38
# 7        366004          2   1/1/2016           NaN      1107461        38
# 8        366005          1   1/1/2016           NaN       844003        33
# 9        366007          1   1/1/2016           NaN      2035771        43
#
#    ProductKey  Quantity Currency Code  \
# 0        1304         1           CAD
# 1        1048         2           USD
# ...

# %%
df_products=pd.read_csv("product.csv")
df_customers=pd.read_csv("customer.csv")
df_stores=pd.read_csv("store.csv")
df_exchangerates=pd.read_csv("exchange_rate.csv")
df_sales=pd.read_csv("sale.csv")

# %%
df_exchangerates
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_sales.info()
df_stores.info()
#df_products.info()
#df_customers.info()
#df_exchangerates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
# ...

# %%
df= pd.merge(df_sales, df_customers, on='ProductKey')

# %%
df= pd.merge(df, df_customers, on='CustomerKey')

# %%
df_complete.drop([#'Order Number', 
        #'Line Item', 'Order Date', 'Delivery Date',
       'CustomerKey',# 'StoreKey', 
       'ProductKey', #'Quantity', 'Currency Code',
       #'Product Name', 'Brand', 'Color', 'Unit Cost USD', 'Unit Price USD',
       'SubcategoryKey', 
       #'Subcategory', 
       'CategoryKey', #'Category', 'Gender',
       #'Name', 'City', 'State', 'Country', 'Continent', 'Birthday'
       ],axis=1,inplace=True)

# %%
df= pd.merge(df_complete, df_stores, on='StoreKey')
df.drop(["StoreKey"],axis=1,inplace=True)
df.to_csv("df.csv",index=False)

# %%
df=pd.read_csv("df.csv")

# %%
revenue_by_store_location = df.groupby(['State_y', 'Country_y'])['Total Spend'].sum().sort_values(ascending=False)
revenue_by_store_location.head(10)
# Out:
# State_y                Country_y
# Online                 Online           11404324.63
# Nevada                 United States     1417885.41
# Kansas                 United States     1394738.06
# Nebraska               United States     1384396.24
# Northwest Territories  Canada            1336150.06
# New Mexico             United States     1325611.89
# Connecticut            United States     1318787.92
# South Carolina         United States     1305684.43
# Oregon                 United States     1302272.44
# Washington DC          United States     1259350.98
# Name: Total Spend, dtype: float64

# %%
data=pd.DataFrame({"state":State_y,"country":Country_y})
data

# %%
#df["Unit Price USD"]=df["Unit Price USD"].str.replace(r'[$,]', '', regex=True)
#df["Unit Cost USD"]=df["Unit Cost USD"].str.replace(',', '', regex=False).str.strip()
df["Unit Price USD"]=df["Unit Price USD"].astype(float)
#df["Unit Price USD"]=df["Unit Price USD"].map('{:.2f}'.format)
df
# Out:
#        Order Number  Line Item Order Date Delivery Date  Quantity  \
# 0            366000          1   1/1/2016           NaN         1
# 1            366001          1   1/1/2016     1/13/2016         2
# 2            366001          2   1/1/2016     1/13/2016         1
# 3            366002          1   1/1/2016     1/12/2016         7
# 4            366002          2   1/1/2016     1/12/2016         1
# ...             ...        ...        ...           ...       ...
# 62879       2243030          1  2/20/2021           NaN         3
# 62880       2243031          1  2/20/2021     2/24/2021         4
# 62881       2243032          1  2/20/2021     2/23/2021         2
# 62882       2243032          2  2/20/2021     2/23/2021         2
# 62883       2243032          3  2/20/2021     2/23/2021         7
#
#       Currency Code                                       Product Name  \
# 0               CAD                    Contoso Lens Adapter M450 White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Number    62884 non-null  int64
#  1   Line Item       62884 non-null  int64
#  2   Order Date      62884 non-null  object
#  3   Delivery Date   13165 non-null  object
#  4   Quantity        62884 non-null  int64
#  5   Currency Code   62884 non-null  object
#  6   Product Name    62884 non-null  object
#  7   Brand           62884 non-null  object
#  8   Color           62884 non-null  object
#  9   Unit Cost USD   62884 non-null  float64
#  10  Unit Price USD  62884 non-null  float64
#  11  Subcategory     62884 non-null  object
#  12  Category        62884 non-null  object
#  13  Gender          62884 non-null  object
#  14  Name            62884 non-null  object
#  15  City            62884 non-null  object
#  16  State_x         62884 non-null  object
# ...

# %%
df['Total Spend'] = df['Quantity'] * df['Unit Price USD']
top_customers = df.groupby('Name')['Total Spend'].sum().sort_values(ascending=False)
top_customers.head(10)
# Out:
# Name
# Matthew Flemming      61871.70
# Stephan Rothstein     45608.27
# Karen Jones           43517.80
# Zrina Topic           42788.04
# Stefanie Hartmann     41521.53
# Gaspare Trevisan      40225.01
# Roy Le                38813.88
# Dennis Weissmuller    38191.06
# Virgie Takacs         37319.88
# Ollie Davis           36817.28
# Name: Total Spend, dtype: float64

# %%
df[df["Name"]=="Susan Schroeder"]
# Out:
#        Order Number  Line Item  Order Date Delivery Date  Quantity  \
# 2507         524007          1    6/7/2016           NaN         8
# 2508         524007          2    6/7/2016           NaN         2
# 2509         524007          3    6/7/2016           NaN         1
# 4568         639003          1   9/30/2016           NaN         1
# 4569         639003          2   9/30/2016           NaN         4
# 4570         639003          3   9/30/2016           NaN         1
# 9098         864003          1   5/13/2017           NaN         3
# 9099         864003          2   5/13/2017           NaN         3
# 9100         864003          3   5/13/2017           NaN         1
# 13595       1071004          1   12/6/2017           NaN         5
# 13596       1071004          2   12/6/2017           NaN         9
# 13597       1071004          3   12/6/2017           NaN         3
# 35600       1598011          1   5/17/2019           NaN         2
# ...

# %%
df= pd.read_csv("Customers.csv", encoding = 'unicode_escape')
df.isnull().sum()
df[df["State Code"].isna()]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
df.fillna("Null",inplace=True)

# %%
df
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01          Null       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20          Null      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df["Unit Price USD"]=df["Unit Price USD"].str.replace(r'[$,]', '', regex=True)
df["Unit Price USD"]=df["Unit Price USD"].astype(float)

# %%
df.to_csv("product.csv",index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
df=df.drop_duplicates().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62884 entries, 0 to 62883
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 62884 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 491.4 KB

# %%
df_clean=df.drop(columns=["Delivery Date"],axis=1)

# %%
df_clean=df

# %%
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
df_clean
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_clean.loc[df_clean["StoreKey"]==0,'Square Meters'] = 0

# %%
df_clean.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
df_clean=df_clean.sort_values(by='StoreKey')

# %%
df_clean.reset_index(drop=True, inplace=True)

# %%
print(df_clean.duplicated().sum())
# Out:
# 0

# %%
df_clean.dropna(inplace=True)

# %%
df.to_csv("df_complete.csv",index=False)

# %%
df["State Code"][df["Country"]=="Canada"].unique()
# Out:
# array(['BC', 'QC', 'ON', 'AB', 'NS', 'SK', 'NU', 'PE', 'MB', 'NL', 'YT',
#        'NT', 'NB'], dtype=object)

# %%
df_clean
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          0         Online                        Online            0.0
# 1          1      Australia  Australian Capital Territory          595.0
# 2          2      Australia            Northern Territory          665.0
# 3          3      Australia               South Australia         2000.0
# 4          4      Australia                      Tasmania         2000.0
# ..       ...            ...                           ...            ...
# 62        62  United States                  South Dakota         1120.0
# 63        63  United States                          Utah         2000.0
# 64        64  United States                 Washington DC         1330.0
# 65        65  United States                 West Virginia         1785.0
# 66        66  United States                       Wyoming          840.0
#
#     Open Date
# 0  2010-01-01
# 1  2008-01-01
# 2  2008-01-12
# 3  2012-01-07
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State        15266 non-null  object
#  5   Country      15266 non-null  object
#  6   Continent    15266 non-null  object
#  7   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 954.3+ KB

# %%
df1=df.groupby('Order Date').size().reset_index(name='Count')

# %%
print(df1)
# Out:
#      Order Date  Count
# 0    2016-01-01     27
# 1    2016-01-02     70
# 2    2016-01-03      2
# 3    2016-01-04     17
# 4    2016-01-05     25
# ...         ...    ...
# 1636 2021-02-16     40
# 1637 2021-02-17     67
# 1638 2021-02-18     63
# 1639 2021-02-19     43
# 1640 2021-02-20     78
#
# [1641 rows x 2 columns]
